# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ORIGINAL MODEL

# %%
train_errors = [5.344,  3.759, 3.159,2.768,  2.479,  2.252, 2.062,   1.899, 1.756, 1.636,  1.561, 1.454, 1.358, 1.276,  1.196,1.124,  1.057,  0.996,  0.937, 0.884, 0.868,  0.818,  0.765,  0.716, 0.673,0.630, 0.592, 0.553, 0.517,  0.484]

# %%
 val_errors = [  4.103,  3.310,2.891,  2.643, 2.444, 2.313,  2.198, 2.108,  2.060,  2.022,  1.975,  1.960,  1.936,  1.908,  1.916,1.904,  1.907,   1.907,  1.912,  1.939,  1.915,  1.915, 1.937,  1.951, 1.960,  1.983,  2.022,  2.053, 2.039,  2.093]

# %%
len(train_errors)
# Out:
# 30

# %%
len(val_errors)
# Out:
# 30

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.plot(train_errors)
plt.plot(val_errors)
plt.title('Training and validation curve of original model')
plt.legend(['train','validation'])
plt.xlabel('epoch')
plt.ylabel('Cross entropy loss')
# Out:
# Text(0, 0.5, 'Cross entropy loss')

# %%
min(val_errors)
# Out:
# 1.904

# %%
val_errors[16-1]
# Out:
# 1.904

# %% [markdown]
# MODEL WITH NHEAD = 4

# %%
train_errors = [5.341, 3.733,  3.131,2.741,   2.451, 2.219,  2.030,  1.872, 1.732,1.609,  1.537,  1.440, 1.351,  1.264, 1.189,  1.118, 1.050,0.993, 0.938, 0.884, 0.833,  0.788,  0.740, 0.699, 0.659,  0.621, 0.583,  0.550,  0.517, 0.487]
val_errors = [4.081,  3.287, 2.861,  2.597,  2.417, 2.269,  2.165, 2.094,  2.040, 1.996,1.965,1.952, 1.921, 1.911, 1.893, 1.896,1.893, 1.898, 1.900, 1.911, 1.932,  1.938, 1.968,  1.966,  1.969,  1.966,  1.995,  2.012,  2.029, 2.065]

# %%
len(train_errors)
# Out:
# 30

# %%
len(val_errors)
# Out:
# 30

# %%
plt.figure()
plt.plot(train_errors)
plt.plot(val_errors)
plt.title('Training and validation curve nhead = 4')
plt.legend(['train','validation'])
plt.xlabel('epoch')
plt.ylabel('Cross entropy loss')
# Out:
# Text(0, 0.5, 'Cross entropy loss')

# %%
min(val_errors)
# Out:
# 1.893

# %%
val_errors[15-1]
# Out:
# 1.893

# %% [markdown]
# MODEL FOR NHEAD = 16

# %%
# Train errors
train_errors = [5.342, 3.770, 3.183, 2.792, 2.503, 2.275, 2.081, 1.917, 1.782, 1.662,
                1.547, 1.444, 1.355, 1.270, 1.192, 1.122, 1.052, 0.989, 0.929, 0.874,
                0.817, 0.769, 0.723, 0.680, 0.639, 0.597, 0.558, 0.560, 0.520, 0.486]

# Val errors
val_errors = [4.105, 3.362, 2.941, 2.657, 2.475, 2.337, 2.223, 2.144, 2.099, 2.037,
              1.997, 1.972, 1.973, 1.990, 1.982, 1.944, 1.940, 1.943, 1.938, 1.945,
              1.979, 2.011, 2.110, 2.138, 2.114, 2.096, 2.106, 2.114, 2.092, 2.090]

# %%
len(train_errors)
# Out:
# 30

# %%
len(val_errors)
# Out:
# 30

# %%
plt.figure()
plt.plot(train_errors)
plt.plot(val_errors)
plt.title('Training and validation curve nhead = 16')
plt.legend(['train','validation'])
plt.xlabel('epoch')
plt.ylabel('Cross entropy loss')
# Out:
# Text(0, 0.5, 'Cross entropy loss')

# %%
min(val_errors)
# Out:
# 1.938

# %%
val_errors[18]
# Out:
# 1.938

# %% [markdown]
# MODEL WITH EMBEDDED DIM 256

# %%
# Training errors
train_errors = [6.407, 4.542, 3.928, 3.551, 3.267, 3.036, 2.841, 2.672, 2.526, 2.393,
                2.276, 2.169, 2.070, 1.981, 1.890, 1.809, 1.739, 1.670, 1.605, 1.546,
                1.517, 1.519, 1.518, 1.516, 1.517, 1.518, 1.516, 1.517, 1.516, 1.517]

# Validation errors
val_errors = [4.962, 4.105, 3.650, 3.334, 3.101, 2.917, 2.768, 2.649, 2.542, 2.457,
              2.390, 2.347, 2.300, 2.225, 2.177, 2.155, 2.105, 2.077, 2.039, 2.026,
              2.026, 2.026, 2.026, 2.026, 2.026, 2.026, 2.026, 2.026, 2.026, 2.026]

# %%
len(train_errors)
# Out:
# 30

# %%
len(val_errors)
# Out:
# 30

# %%
plt.figure()
plt.plot(train_errors)
plt.plot(val_errors)
plt.title('Training and validation curve layer dim = 256')
plt.legend(['train','validation'])
plt.xlabel('epoch')
plt.ylabel('Cross entropy loss')
# Out:
# Text(0, 0.5, 'Cross entropy loss')

# %%
min(val_errors)
# Out:
# 2.026

# %%
val_errors[20-1]
# Out:
# 2.026

# %% [markdown]
# MODEL WITH EMBEDDED DIM 1024

# %%
# Training errors
train_errors = [4.496, 3.003, 2.402, 2.032, 1.763, 1.607, 1.414, 1.270, 1.144, 1.075, 0.995, 0.892, 0.799, 0.749, 0.666, 0.597]

# Validation errors
val_errors = [3.361, 2.591, 2.278, 2.082, 1.981, 1.900, 1.864, 1.845, 1.834, 1.827, 1.819, 1.807, 1.827, 1.842, 1.895, 1.934]

# %%
len(train_errors)
# Out:
# 16

# %%
len(val_errors)
# Out:
# 16

# %%
plt.figure()
plt.plot(train_errors)
plt.plot(val_errors)
plt.title('Training and validation curve layer dim 1024')
plt.legend(['train','validation'])
plt.xlabel('epoch')
plt.ylabel('Cross entropy loss')
# Out:
# Text(0, 0.5, 'Cross entropy loss')

# %%
min(val_errors)
# Out:
# 1.807

# %%
val_errors[12-1]
# Out:
# 1.807
